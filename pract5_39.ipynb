# %%
# Name: Anubhav Kumar Tiwary 
# PRN:2301208039

# %%
# importing necessary libraries
import pandas as pd
import datetime as dt
import numpy as np
 
# importing the data
df = pd.read_csv("SuperStore_Sales_Dataset.csv", encoding='latin1')  # or try 'latin1' if utf-8 doesn't work
df.head()
# Out:
#    ï»¿Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                 3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                 8604  US-2019-116365  03-01-2019  08-01-2019
#
#         Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0  Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 1  Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 2  Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 3     First Class    LR-16915       Lena Radford   Consumer  United States
# 4  Standard Class    CA-12310  Christine Abelman  Corporate  United States
#
#            City  ...         Category Sub-Category  \
# 0  Gaithersburg  ...        Furniture    Bookcases
# ...

# %% [markdown]
# **Calculating Recency**

# %%
import pandas as pd

df_recency['LastPurchaseDate'] = pd.to_datetime(df_recency['LastPurchaseDate'])
recent_date = df_recency['LastPurchaseDate'].max()
df_recency['Recency'] = df_recency['LastPurchaseDate'].apply(
    lambda x: (recent_date - x).days)
print(df_recency.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
# ----> 3 df_recency['LastPurchaseDate'] = pd.to_datetime(df_recency['LastPurchaseDate'])
#       4 recent_date = df_recency['LastPurchaseDate'].max()
#       5 df_recency['Recency'] = df_recency['LastPurchaseDate'].apply(
#       6     lambda x: (recent_date - x).days)
#
# NameError: name 'df_recency' is not defined
